# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mlt

# %%
df = pd.read_csv("C:/Users/SAM/Python for DS/train-chennai-sale.csv")

# %%
# df.head()
#df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRT_ID         7109 non-null   object
#  1   AREA           7109 non-null   object
#  2   INT_SQFT       7109 non-null   int64
#  3   DATE_SALE      7109 non-null   object
#  4   DIST_MAINROAD  7109 non-null   int64
#  5   N_BEDROOM      7108 non-null   float64
#  6   N_BATHROOM     7104 non-null   float64
#  7   N_ROOM         7109 non-null   int64
#  8   SALE_COND      7109 non-null   object
#  9   PARK_FACIL     7109 non-null   object
#  10  DATE_BUILD     7109 non-null   object
#  11  BUILDTYPE      7109 non-null   object
#  12  UTILITY_AVAIL  7109 non-null   object
#  13  STREET         7109 non-null   object
#  14  MZZONE         7109 non-null   object
#  15  QS_ROOMS       7109 non-null   float64
#  16  QS_BATHROOM    7109 non-null   float64
# ...

# %% [markdown]
# Above used commands are used to get Count of row/column,information, type of data inside data frame

# %%
df.isnull().sum()
# Out:
# PRT_ID           0
# AREA             0
# INT_SQFT         0
# DATE_SALE        0
# DIST_MAINROAD    0
# N_BEDROOM        0
# N_BATHROOM       0
# N_ROOM           0
# SALE_COND        0
# PARK_FACIL       0
# DATE_BUILD       0
# BUILDTYPE        0
# UTILITY_AVAIL    0
# STREET           0
# MZZONE           0
# QS_ROOMS         0
# QS_BATHROOM      0
# QS_BEDROOM       0
# QS_OVERALL       0
# REG_FEE          0
# COMMIS           0
# SALES_PRICE      0
# dtype: int64

# %%
# x = df["N_BEDROOM"].mode()[0]
# df["N_BEDROOM"].fillna(x, inplace = True)
df.fillna(0, inplace=True) #this fuction will replace all blank cell with 0

# %%
df.isnull().sum()
# Out:
# PRT_ID           0
# AREA             0
# INT_SQFT         0
# DATE_SALE        0
# DIST_MAINROAD    0
# N_BEDROOM        0
# N_BATHROOM       0
# N_ROOM           0
# SALE_COND        0
# PARK_FACIL       0
# DATE_BUILD       0
# BUILDTYPE        0
# UTILITY_AVAIL    0
# STREET           0
# MZZONE           0
# QS_ROOMS         0
# QS_BATHROOM      0
# QS_BEDROOM       0
# QS_OVERALL       0
# REG_FEE          0
# COMMIS           0
# SALES_PRICE      0
# dtype: int64

# %%
df
# Out:
#       PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0     P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1     P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2     P01812       Adyar       909  04-02-2012             70        1.0
# 3     P05346   Velachery      1855  13-03-2010             14        3.0
# 4     P06210  Karapakkam      1226  05-10-2009             84        1.0
# ...      ...         ...       ...         ...            ...        ...
# 7104  P03834  Karapakkam       598  03-01-2011             51        1.0
# 7105  P10000   Velachery      1897  08-04-2004             52        3.0
# 7106  P09594   Velachery      1614  25-08-2006            152        2.0
# 7107  P06508  Karapakkam       787  03-08-2009             40        1.0
# 7108  P09794   Velachery      1896  13-07-2005            156        3.0
#
#       N_BATHROOM  N_ROOM    SALE_COND PARK_FACIL  ... UTILITY_AVAIL  \
# ...

# %%
df.AREA.unique()
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KK Nagar', 'TNagar', 'T Nagar', 'Chrompt', 'Chrmpet', 'Karapakam',
#        'Ana Nagar', 'Chormpet', 'Adyr', 'Velchery', 'Ann Nagar',
#        'KKNagar'], dtype=object)

# %%
df.AREA = df.AREA.replace({'Karapakam':'Karapakkam', 'Ana Nagar':'Anna Nagar', 'Adyr':'Adyar', 
                           'Velchery':'Velachery', 'KKNagar':'KK Nagar', 'TNagar':'T Nagar', 
                           'Chrmpet':'Chromepet', 'Chrompet':'Chromepet','Chrompt': 'Chromepet', 
                           'Chormpet':'Chromepet', 'Ann Nagar':'Anna Nagar'})

# %%
df.AREA.unique() #rechecking if all value are replaced
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chromepet',
#        'KK Nagar', 'T Nagar'], dtype=object)

# %%
df.SALE_COND.unique()
# Out:
# array(['AbNormal', 'Family', 'Partial', 'AdjLand', 'Normal Sale',
#        'Ab Normal', 'Partiall', 'Adj Land', 'PartiaLl'], dtype=object)

# %%
df.SALE_COND = df.SALE_COND.replace({'Ab Normal':'AbNormal', 'PartiaLl':'Partial', 'Adj Land':'AdjLand','Partiall':'Partial'})
df.SALE_COND.unique() #recheck
# Out:
# array(['AbNormal', 'Family', 'Partial', 'AdjLand', 'Normal Sale'],
#       dtype=object)

# %%
df.PARK_FACIL.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.PARK_FACIL=df.PARK_FACIL.replace({'Noo':'No'})
df.PARK_FACIL.unique() #recheck
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.UTILITY_AVAIL.unique()
# Out:
# array(['AllPub', 'ELO', 'NoSewr'], dtype=object)

# %%
df.UTILITY_AVAIL=df.UTILITY_AVAIL.replace({'NoSeWa':'NoSewr',
                                          'All Pub':'AllPub','NoSewr ':'NoSewr'})
df.UTILITY_AVAIL.unique() #recheck
# Out:
# array(['AllPub', 'ELO', 'NoSewr'], dtype=object)

# %%
df.STREET.unique()
# Out:
# array(['Paved', 'Gravel', 'NoAccess'], dtype=object)

# %%
df.STREET=df.STREET.replace({'No Access':'NoAccess', 'Pavd':'Paved'})
df.STREET.unique() #recheck
# Out:
# array(['Paved', 'Gravel', 'NoAccess'], dtype=object)

# %%
df.BUILDTYPE.unique()
# Out:
# array(['Commercial', 'Others', 'Other', 'House', 'Comercial'],
#       dtype=object)

# %%
df.BUILDTYPE=df.BUILDTYPE.replace({'Other':'Others', 'Comercial':'Commercial'})
df.BUILDTYPE.unique()
# Out:
# array(['Commercial', 'Others', 'House'], dtype=object)

# %%
df.dtypes
# Out:
# AREA                     object
# INT_SQFT                  int64
# DATE_SALE        datetime64[ns]
# DIST_MAINROAD             int64
# N_BEDROOM                 int32
# N_BATHROOM                int32
# N_ROOM                    int64
# SALE_COND                object
# PARK_FACIL               object
# DATE_BUILD       datetime64[ns]
# BUILDTYPE                object
# UTILITY_AVAIL            object
# STREET                   object
# MZZONE                   object
# QS_ROOMS                float64
# QS_BATHROOM             float64
# QS_BEDROOM              float64
# QS_OVERALL              float64
# SALES_PRICE               int64
# dtype: object

# %% [markdown]
# As per real life logic bedroom and bathroom are always represented as 1,2,3.. not 2.0 or 3.0, thereforewe will change its type

# %%
df.N_BEDROOM = df.N_BEDROOM.astype(int)
df.N_BATHROOM = df.N_BATHROOM.astype(int)
df.dtypes
# Out:
# AREA                     object
# INT_SQFT                  int64
# DATE_SALE        datetime64[ns]
# DIST_MAINROAD             int64
# N_BEDROOM                 int32
# N_BATHROOM                int32
# N_ROOM                    int64
# SALE_COND                object
# PARK_FACIL               object
# DATE_BUILD       datetime64[ns]
# BUILDTYPE                object
# UTILITY_AVAIL            object
# STREET                   object
# MZZONE                   object
# QS_ROOMS                float64
# QS_BATHROOM             float64
# QS_BEDROOM              float64
# QS_OVERALL              float64
# SALES_PRICE               int64
# dtype: object

# %%
df.DATE_SALE = pd.to_datetime(df.DATE_SALE, format='%d-%m-%Y')
df.DATE_BUILD = pd.to_datetime(df.DATE_BUILD, format='%d-%m-%Y')
#we will use "y" if year is given in this format=12-12-94, else we will use "Y" if date formate is 12-12-1994

# %%
df.dtypes
# Out:
# AREA                     object
# INT_SQFT                  int64
# DATE_SALE        datetime64[ns]
# DIST_MAINROAD             int64
# N_BEDROOM                 int32
# N_BATHROOM                int32
# N_ROOM                    int64
# SALE_COND                object
# PARK_FACIL               object
# DATE_BUILD       datetime64[ns]
# BUILDTYPE                object
# UTILITY_AVAIL            object
# STREET                   object
# MZZONE                   object
# QS_ROOMS                float64
# QS_BATHROOM             float64
# QS_BEDROOM              float64
# QS_OVERALL              float64
# SALES_PRICE               int64
# dtype: object

# %%
df = df.drop_duplicates()

# %%
del df['PRT_ID']
del df['REG_FEE']
del df['COMMIS']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PRT_ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df
# Out:
#             AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 0     Karapakkam      1004 2011-05-04            131          1           1
# 1     Anna Nagar      1986 2006-12-19             26          2           1
# 2          Adyar       909 2012-02-04             70          1           1
# 3      Velachery      1855 2010-03-13             14          3           2
# 4     Karapakkam      1226 2009-10-05             84          1           1
# ...          ...       ...        ...            ...        ...         ...
# 7104  Karapakkam       598 2011-01-03             51          1           1
# 7105   Velachery      1897 2004-04-08             52          3           2
# 7106   Velachery      1614 2006-08-25            152          2           1
# 7107  Karapakkam       787 2009-08-03             40          1           1
# 7108   Velachery      1896 2005-07-13            156          3           2
#
# ...

# %%
df['Age']=df.DATE_SALE.dt.year-df.DATE_BUILD.dt.year

# %%
df
# Out:
#             AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 0     Karapakkam      1004 2011-05-04            131          1           1
# 1     Anna Nagar      1986 2006-12-19             26          2           1
# 2          Adyar       909 2012-02-04             70          1           1
# 3      Velachery      1855 2010-03-13             14          3           2
# 4     Karapakkam      1226 2009-10-05             84          1           1
# ...          ...       ...        ...            ...        ...         ...
# 7104  Karapakkam       598 2011-01-03             51          1           1
# 7105   Velachery      1897 2004-04-08             52          3           2
# 7106   Velachery      1614 2006-08-25            152          2           1
# 7107  Karapakkam       787 2009-08-03             40          1           1
# 7108   Velachery      1896 2005-07-13            156          3           2
#
# ...
